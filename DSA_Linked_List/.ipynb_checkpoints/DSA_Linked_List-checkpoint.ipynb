# %%
"""
控制问题的维度

看大体思路，然后自己写


边做边接近

粗框架 加 探测器

"""

# %% [markdown]
# ```cpp
# // Definition for singly-linked list.
# struct SinglyListNode {
#     int val;
#     SinglyListNode *next;
#     SinglyListNode(int x) : val(x), next(NULL) {}
# };
#
# ```

# %% [markdown]
# ## Design Linked List

# %%
text = r"""
C:\Users\Goose\Documents\Udacity_Cpp\Cpp_Code\2_Foundations\02_Introduction_to_the_C++_Language\02_Write_Your_First_C++_Program 
"""
print(text.replace('\\','/'))
# Out:
# C:/Users/Goose/Documents/Udacity_Cpp/Cpp_Code/2_Foundations/02_Introduction_to_the_C++_Language/02_Write_Your_First_C++_Program

# %% [markdown]
# ```cpp
# class Node {
#     Node(value){
#     self.val = value
#     self.next = None
#     }
# };
#
#
# class MyLinkedList {
# public:
#     /** Initialize your data structure here. */
#     MyLinkedList() {
#         self.head = None
#
#     }
#
#     /** Get the value of the index-th node in the linked list. If the index is invalid, return -1. */
#     int get(int index) {
#
#         next = self.head
#         for i in range(index):
#             next = next.next
#         return next.value
#     }
#
#     /** Add a node of value val before the first element of the linked list. After the insertion, the new node will be the first node of the linked list. */
#     void addAtHead(int val) {
#         new_head = Node(val)
#         new_head.next = self.head
#         self.head = new_head
#     }
#
#     /** Append a node of value val to the last element of the linked list. */
#     void addAtTail(int val) {
#         next = self.head
#         for i in range(index):
#             next = next.next
#
#         next.next = Node(value)
#
#     }
#
#     /** Add a node of value val before the index-th node in the linked list. If index equals to the length of linked list, the node will be appended to the end of linked list. If index is greater than the length, the node will not be inserted. */
#     void addAtIndex(int index, int val) {
#         next_node = self.head
#         for i in range(index):
#             next_node = next_node.next
#
#         new_node = Node(val)
#         new_node.next = next_node.next
#         next_node.next = new_node
#     }
#
#     /** Delete the index-th node in the linked list, if the index is valid. */
#     void deleteAtIndex(int index) {
#         next_node = self.head
#         for i in range(index):
#             next_node = next_node.next
#         delete_node = next_node.next
#         next_node.next = delete_node.next
#     }
# };
#
# /**
#  * Your MyLinkedList object will be instantiated and called as such:
#  * MyLinkedList* obj = new MyLinkedList();
#  * int param_1 = obj->get(index);
#  * obj->addAtHead(val);
#  * obj->addAtTail(val);
#  * obj->addAtIndex(index,val);
#  * obj->deleteAtIndex(index);
#  */
#
# ```

# %% [markdown]
# ```cpp
# #include <iostream>
#
# using namespace std;
#
# struct node
# {
#     int data;
#     node *next;
# };
#
# class linked_list
# {
# private:
#     node *head,*tail;
# public:
#     linked_list()
#     {
#         head = NULL;
#         tail = NULL;
#     }
#
#     void add_node(int n)
#     {
#         node *tmp = new node;
#         tmp->data = n;
#         tmp->next = NULL;
#
#         if(head == NULL)
#         {
#             head = tmp;
#             tail = tmp;
#         }
#         else
#         {
#             tail->next = tmp;
#             tail = tail->next;
#         }
#     }
# };
#
# int main()
# {
#     linked_list a;
#     a.add_node(1);
#     a.add_node(2);
#     return 0;
# }
# ```

# %% [markdown]
# ## Aeccepted Linked List

# %% [markdown]
# https://leetcode.com/explore/learn/card/linked-list/209/singly-linked-list/1290/

# %% [markdown]
# ```cpp
# // Use basic first
#
# class Node {
#     public:
#         int data;
#         Node *next;
#         Node(int d){
#             data=d;
#             next = NULL;
#         }
#
#     };
#
#
# class MyLinkedList {
# public:
#     Node *head;
#     int n;
#     /** Initialize your data structure here. */
#     MyLinkedList() {
#         head = NULL;
#         n = 0;
#     }
#
#     /** Get the value of the index-th node in the linked list. If the index is invalid, return -1. */
#     int get(int index) {
#         if(index>=n || index <0)
#             return -1;
#
#         Node *temp=head;
#         for(int i=0;i<index;i++)
#             temp=temp->next;
#         return temp->data;
#     }
#
#     /** Add a node of value val before the first element of the linked list. After the insertion, the new node will be the first node of the linked list. */
#     void addAtHead(int val) {
#         Node *new_head = new Node(val);
#         if(head ==NULL)
#             head = new_head;
#         else{
#             new_head->next = head;
#             head = new_head;
#         }
#         n++;
#
#     }
#
#     /** Append a node of value val to the last element of the linked list. */
#     void addAtTail(int val) {
#         Node *new_node = new Node(val);
#         if(n==0){
#             head = new_node;
#         }else{
#         Node *temp=head;
#         for(int i=0;i<n-1;i++)
#             temp=temp->next;
#         temp->next = new_node;
#             }
#         n++;
#     }
#
#     /** Add a node of value val before the index-th node in the linked list. If index equals to the length of linked list, the node will be appended to the end of linked list. If index is greater than the length, the node will not be inserted. */
#     void addAtIndex(int index, int val) {
#         Node *new_node = new Node(val);
#
#         if(index>n || index <0){
#             return;
#         }
#
#         if(index==0){
#             new_node->next = head;
#             head = new_node;
#             n++;
#             return;
#
#         }
#
#
#         Node *temp = head;
#         for(int i=0;i<index-1;i++)
#             temp=temp->next;
#
#         new_node->next = temp->next;
#         temp->next = new_node;
#         n++;
#     }
#
#     /** Delete the index-th node in the linked list, if the index is valid. */
#     void deleteAtIndex(int index) {
#         if(index>=n || index <0){
#             return;
#         }
#
#         if(n==1){
#             head = NULL;
#             n--;
#             return;}
#
#         if(index==0){
#             head = head->next;
#             n--;
#         }
#
#
#         Node *temp = head;
#         for(int i=0;i<index-1;i++)
#             temp=temp->next;
#
#         Node *temp2 = temp->next;
#         if(temp2){
#
#             temp->next = temp2->next;
#         }
#         else
#             temp->next = NULL;
#         n--;
#     }
# };
#
# /**
#  * Your MyLinkedList object will be instantiated and called as such:
#  * MyLinkedList* obj = new MyLinkedList();
#  * int param_1 = obj->get(index);
#  * obj->addAtHead(val);
#  * obj->addAtTail(val);
#  * obj->addAtIndex(index,val);
#  * obj->deleteAtIndex(index);
#  */
# ```

# %% [markdown]
# ### Solutions
#
# ### Please recap later
# https://leetcode.com/explore/learn/card/linked-list/209/singly-linked-list/1298/
#
# ```cpp
# // Definition for singly-linked list.
# struct SinglyListNode {
#     int val;
#     SinglyListNode *next;
#     SinglyListNode(int x) : val(x), next(NULL) {}
# };
#
# class MyLinkedList {
# private:
#     SinglyListNode *head;
# public:
#     /** Initialize your data structure here. */
#     MyLinkedList() {
#         head = NULL;
#     }
# };
#
#
# /** Helper function to return the index-th node in the linked list. */
# SinglyListNode* getNode(int index) {
#     SinglyListNode *cur = head;
#     for (int i = 0; i < index && cur; ++i) {
#         cur = cur->next;
#     }
#     return cur;
# }
# /** Helper function to return the last node in the linked list. */
# SinglyListNode* getTail() {
#     SinglyListNode *cur = head;
#     while (cur && cur->next) {
#         cur = cur->next;
#     }
#     return cur;
# }
# /** Get the value of the index-th node in the linked list. If the index is invalid, return -1. */
# int get(int index) {
#     SinglyListNode *cur = getNode(index);
#     return cur == NULL ? -1 : cur->val;
# }
#
#
# /** Add a node of value val before the first element of the linked list. After the insertion, the new node will be the first node of the linked list. */
# void addAtHead(int val) {
#     SinglyListNode *cur = new SinglyListNode(val);
#     cur->next = head;
#     head = cur;
#     return;
# }
#
# /** Append a node of value val to the last element of the linked list. */
# void addAtTail(int val) {
#     if (head == NULL) {
#         addAtHead(val);
#         return;
#     }
#     SinglyListNode *prev = getTail();
#     SinglyListNode *cur = new SinglyListNode(val);
#     prev->next = cur;
# }
#
# /** Add a node of value val before the index-th node in the linked list. If index equals to the length of linked list, the node will be appended to the end of linked list. If index is greater than the length, the node will not be inserted. */
# void addAtIndex(int index, int val) {
#     if (index == 0) {
#         addAtHead(val);
#         return;
#     }
#     SinglyListNode *prev = getNode(index - 1);
#     if (prev == NULL) {
#         return;
#     }
#     SinglyListNode *cur = new SinglyListNode(val);
#     SinglyListNode *next = prev->next;
#     cur->next = next;
#     prev->next = cur;
# }
#
#
# /** Delete the index-th node in the linked list, if the index is valid. */
# void deleteAtIndex(int index) {
#     SinglyListNode *cur = getNode(index);
#     if (cur == NULL) {
#         return;
#     }
#     SinglyListNode *prev = getNode(index - 1);
#     SinglyListNode *next = cur->next;
#     if (prev) {
#         prev->next = next;
#     } else {
#         // modify head when deleting the first node.
#         head = next;
#     }
# }
#
# ```

# %% [markdown]
# ## Linked List Cycle

# %% [markdown]
# ```cpp
# /**
#  * Definition for singly-linked list.
#  * struct ListNode {
#  *     int val;
#  *     ListNode *next;
#  *     ListNode(int x) : val(x), next(NULL) {}
#  * };
#  */
# class Solution {
# public:
#     bool hasCycle(ListNode *head) {
#         ListNode *slow, *fast;
#         slow = head;
#         fast = head;
#
#         while (fast && fast->next && fast->next->next){
#             fast = fast->next->next;
#             slow = slow->next;
#             if(fast==slow){
#                 return true;
#             }
#         }
#         return false;
#     }
# };
# ```

# %% [markdown]
# ## Linked List Cycle II

# %% [markdown]
# ```cpp
# class Solution {
# public:
#     ListNode *detectCycle(ListNode *head) {
#         ListNode *slow, *fast;
#         slow = head;
#         fast = head;
#
#         bool loop=false;
#         while (fast && fast->next && fast->next->next){
#             fast = fast->next->next;
#             slow = slow->next;
#             if(fast==slow){
#                 loop = true;
#                 break;
#             }
#         }
#
#         if(!loop){
#             return NULL;
#         }else{
#             slow = head;
#             while(slow!=fast){
#                 slow = slow->next;
#                 fast = fast->next;
#             }
#             return slow;
#         }
#
#     }
# };
# ```

# %%
#### Use hash table
class Solution(object):
    def detectCycle(self, head):
        visited = set()

        node = head
        while node is not None:
            if node in visited:
                return node
            else:
                visited.add(node)
                node = node.next

        return None

# %% [markdown]
# ## Intersection of Two Linked Lists

# %% [markdown]
# https://leetcode.com/explore/learn/card/linked-list/214/two-pointer-technique/1215/

# %% [markdown]
# ```cpp
# /**
#  * Definition for singly-linked list.
#  * struct ListNode {
#  *     int val;
#  *     ListNode *next;
#  *     ListNode(int x) : val(x), next(NULL) {}
#  * };
#  */
#
#  struct ListNodeCounter {
#       ListNode *val;
#       ListNodeCounter *next;
#       ListNodeCounter(ListNode *x): val(x), next(NULL) {}
#
#  };
#
# class Solution {
# public:
#     ListNode *getIntersectionNode(ListNode *headA, ListNode *headB) {
#
#         //Forward
#         ListNode *listA, *listB;
#         //int numA=0;
#         //int numB=0;
#         listA = headA;
#         listB = headB;
#
#
#         ListNodeCounter *counterA, *counterB;
#         counterA =  new ListNodeCounter(headA);
#         counterB = new ListNodeCounter(headB);
#
#
#         while (listA->next){
#             listA = listA->next;
#             //numA++;
#             ListNodeCounter *cur = new ListNodeCounter(listA);
#             cur->next =  counterA;
#             counterA = cur;
#
#         }
#
#         while(listB->next){
#             listB = listB->next;
#             //numB++;
#             ListNodeCounter *cur = new ListNodeCounter(listB);
#             cur->next =  counterB;
#             counterB = cur;
#         }
#
#
#         // cout<<counterA->val<<"\n";
#         // cout<<counterB->val<<"\n";
#          // cout<<counterA->next->val<<"\n";
#         //Backward
#         while(counterA->val==counterB->val
#                   and counterA->next
#                   and counterB->next
#                   and counterA->next->val==counterB->next->val){
#
#             // cout<<counterA->val<<"\n";
#             // cout<<counterB->val<<"\n";
#
#             counterA=counterA->next;
#             counterB=counterB->next;
#
#             // cout<<counterA->val<<"\n";
#             // cout<<counterB->val<<"\n";
#         }
#
#
#          cout<<counterA->val<<"\n";
#
#         if(counterA->val!=counterB->val)
#             return NULL;
#         else
#             return counterA->val;
#         // return 0;
#     }
# };
# ```

# %% [markdown]
# ###  Solutions
# https://leetcode.com/problems/intersection-of-two-linked-lists/solution/

# %% [markdown]
# ```cpp
# class Solution {
# public:
#     ListNode *getIntersectionNode(ListNode *headA, ListNode *headB) {
#         ListNode *pA = headA;
#         ListNode *pB = headB;
#         while (pA != pB) {
#             pA = pA == nullptr ? headB : pA->next;
#             pB = pB == nullptr ? headA : pB->next;
#         }
#         return pA;
#         // Note: In the case lists do not intersect, the pointers for A and B
#         // will still line up in the 2nd iteration, just that here won't be
#         // a common node down the list and both will reach their respective ends
#         // at the same time. So pA will be NULL in that case.
#     }
# };
#
# ```

# %% [markdown]
# ## Remove Nth Node From End of List

# %% [markdown]
# https://leetcode.com/explore/learn/card/linked-list/214/two-pointer-technique/1296/

# %% [markdown]
# #### 最后记得修剪一下

# %% [markdown]
# ```cpp
# /**
#  * Definition for singly-linked list.
#  * struct ListNode {
#  *     int val;
#  *     ListNode *next;
#  *     ListNode() : val(0), next(nullptr) {}
#  *     ListNode(int x) : val(x), next(nullptr) {}
#  *     ListNode(int x, ListNode *next) : val(x), next(next) {}
#  * };
#  */
# class Solution {
# public:
#     ListNode* removeNthFromEnd(ListNode* head, int n) {
#
#
#
#         ListNode *slow, *fast;
#
#         slow = head;
#         fast = head;
#         while(n>=0 and fast){
#             fast = fast->next;
#             n--;
#         }
#
#         // cout<<n<<"\n";
#         // cout<<fast->val<<"\n";
#
#
#         if(n==-1){
#
#             while(fast){
#                 slow = slow->next;
#                 fast = fast->next;
#             }
#             slow->next = slow->next->next;
#         }
#         else
#             head = head->next;
#
#         return head;
#
#     }
# };
#
# ```

# %% [markdown]
# ## Two-Pointer in Linked List Template

# %% [markdown]
# ```cpp
# // Initialize slow & fast pointers
# ListNode* slow = head;
# ListNode* fast = head;
# /**
#  * Change this condition to fit specific problem.
#  * Attention: remember to avoid null-pointer error
#  **/
# while (slow && fast && fast->next) {
#     slow = slow->next;          // move slow pointer one step each time
#     fast = fast->next->next;    // move fast pointer two steps each time
#     if (slow == fast) {         // change this condition to fit specific problem
#         return true;
#     }
# }
# return false;   // change return value to fit specific problem
#
# ```

# %% [markdown]
# # Classic Problems

# %% [markdown]
# ## Reverse Linked List

# %% [markdown]
# ```cpp
# /**
#  * Definition for singly-linked list.
#  * struct ListNode {
#  *     int val;
#  *     ListNode *next;
#  *     ListNode() : val(0), next(nullptr) {}
#  *     ListNode(int x) : val(x), next(nullptr) {}
#  *     ListNode(int x, ListNode *next) : val(x), next(next) {}
#  * };
#  */
# class Solution {
# public:
#     ListNode* reverseList(ListNode* head) {
#
#         if(!head)
#             return nullptr;
#
#         ListNode *pre= head;
#         ListNode *temp;
#         ListNode *first= head;
#         while(head){
#             temp = head->next;
#             head->next = pre;
#             pre = head;
#             if(temp)
#                 head = temp;
#             else
#                 break;
#
#             // cout<<head->val<<"\n";
#             // cout<<head->next<<"\n";
#             // cout<<pre->next<<"\n";
#
#         }
#         first->next=nullptr;
#
#     // cout<<first->val<<"\n";
#     // cout<<head->next<<"\n";
#     return head;
#
#     }
# };
# ```

# %% [markdown]
# #### Std
# https://leetcode.com/explore/learn/card/linked-list/219/classic-problems/1206/
# ```cpp
# /**
#  * Definition for singly-linked list.
#  * struct ListNode {
#  *     int val;
#  *     ListNode *next;
#  *     ListNode(int x) : val(x), next(NULL) {}
#  * };
#  */
# class Solution {
# public:
#     ListNode* reverseList(ListNode* head) {
#         if (head == NULL) {
#             return head;
#         }
#         ListNode* currentHead = head;
#         while (head->next) {
#             ListNode* p = head->next;
#             head->next = p->next;
#             p->next = currentHead;
#             currentHead = p;
#         }
#         return currentHead;
#     }
# };
#
# ```

# %% [markdown]
# ## Remove Linked List Elements

# %% [markdown]
# https://leetcode.com/explore/learn/card/linked-list/219/classic-problems/1207/

# %% [markdown]
# ```cpp
# /**
#  * Definition for singly-linked list.
#  * struct ListNode {
#  *     int val;
#  *     ListNode *next;
#  *     ListNode() : val(0), next(nullptr) {}
#  *     ListNode(int x) : val(x), next(nullptr) {}
#  *     ListNode(int x, ListNode *next) : val(x), next(next) {}
#  * };
#  */
# class Solution {
# public:
#     ListNode* removeElements(ListNode* head, int val) {
#
#
#         // To new valid head
#         while(head){
#             if(head->val==val){
#                 head = head->next;
#             }else
#                 break;
#         }
#
#         ListNode* temp = head;
#         while (temp and temp->next) {
#             if(temp->next->val==val){
#                 temp->next=temp->next->next;
#             }else
#                 temp=temp->next;
#         }
#         return head;
#
#     }
# };
# ```

# %% [markdown]
# ## Odd Even Linked List

# %% [markdown]
# https://leetcode.com/explore/learn/card/linked-list/219/classic-problems/1208/

# %% [markdown]
# ```cpp
# /**
#  * Definition for singly-linked list.
#  * struct ListNode {
#  *     int val;
#  *     ListNode *next;
#  *     ListNode() : val(0), next(nullptr) {}
#  *     ListNode(int x) : val(x), next(nullptr) {}
#  *     ListNode(int x, ListNode *next) : val(x), next(next) {}
#  * };
#  */
# class Solution {
#
# public:
#     ListNode* oddEvenList(ListNode* head) {
#
#         ListNode *tmp;
#
#         // cout<<"tata\n";
#         // tmp=head;
#         // while(tmp){
#         //     cout<<tmp->val<<"\n";
#         //     tmp = tmp->next;
#         // }
#
#
#         if(!head or !head->next)
#             return head;
#
#         //Find tail
#         ListNode *pre=nullptr;
#         ListNode *tail=head;
#         int n=1;
#         while(tail->next){
#             pre = tail;
#             tail = tail->next;
#             n++;
#         }
#
#         ListNode *oddTail;
#
#         if(n%2==0)
#             oddTail = pre;
#         else
#             oddTail = tail;
#
#         ListNode *last;
#         if(oddTail->next)
#             last = oddTail->next;
#
#
#
#
# //         cout<<"tata\n";
# //         tmp=head;
# //         while(tmp){
# //             cout<<tmp->val<<"\n";
# //             tmp = tmp->next;
# //         }
#
#
#         // cout<<"tata\n";
#         // cout<<oddTail->val<<"\n";
#
#         // Move
#         int m=1;
#         ListNode *current=head;
#         ListNode *tmp1,*tmp2,*tmp3;
#
#         pre=oddTail;
#         while(current and current!=oddTail and current->next){
#             // if(m%2!=0){
#                 tmp1 = pre->next;
#                 tmp2 = current->next;
#                 tmp3 = tmp2->next;
#                 pre->next = tmp2;
#                 tmp2->next = tmp1;
#                 pre = tmp2;
#                 current->next = tmp3;
#                 current = tmp3;
#
# //                 cout<<"tata\n";
# //                 if(tmp1)
# //                     cout<<tmp1->val<<"\n";
# //                 else
# //                     cout<<NULL<<"\n";
# //                 cout<<tmp2->val<<"\n";
# //                 cout<<tmp3->val<<"\n";
#
#
# //                 cout<<"tata List\n";
# //                 tmp=head;
# //                 while(tmp){
# //                     cout<<tmp->val<<"\n";
# //                     tmp = tmp->next;
# //                 }
#
#
#             // }else{
#             //     current = current->next;
#             // }
#             // m++;
#         }
#
#
# //         cout<<"tata\n";
# //         tmp=head;
# //         while(tmp){
# //             cout<<tmp->val<<"\n";
# //             tmp = tmp->next;
# //         }
#
#
#         // cout<<"tata\n";
#         // cout<<(current)<<"\n";
#         // cout<<(current!=oddTail)<<"\n";
#         // cout<<(current->next)<<"\n";
#         // cout<<(current->val)<<"\n";
#         // cout<<(pre->val)<<"\n";
#         // cout<<(pre->val)<<"\n";
#
#         // if(last){
#         //     oddTail->next = last;
#         // }
#
#         // cout<<"tata\n";
#         // tmp=head;
#         // while(tmp){
#         //     cout<<tmp->val<<"\n";
#         //     tmp = tmp->next;
#         // }
#
#
#         return head;
#     }
# };
# ```

# %% [markdown]
# ## Detector

# %% [markdown]
# ----
# ```cpp
#
#         cout<<"tata\n";
#         if(tmp1)
#             cout<<tmp1->val<<"\n";
#         else
#             cout<<NULL<<"\n";
#         cout<<tmp2->val<<"\n";
#         cout<<tmp3->val<<"\n";
#
#
#         cout<<"tata List\n";
#         tmp=head;
#         while(tmp){
#             cout<<tmp->val<<"\n";
#             tmp = tmp->next;
#         }
#
# ```
# ----
