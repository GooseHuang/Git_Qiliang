# %%
"""

Tree and Graph, 把事物有效组织和联系起来的工具



"""

# %% [markdown]
# ### Graph Representation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Adjacency Matricies

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### DFS
# ![image.png](attachment:image.png)
