# %%
"""
体验过

Try a bunch

"""

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Normalzation
# ![image.png](attachment:image.png)

# %% [markdown]
# # Flatterning
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Input and output
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Class score
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Structures
# ![image.png](attachment:image.png)
