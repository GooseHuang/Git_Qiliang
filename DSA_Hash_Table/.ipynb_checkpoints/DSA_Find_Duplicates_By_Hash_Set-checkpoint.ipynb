# %% [markdown]
# ![image.png](attachment:image.png)

# %%
### CPP

# %% [markdown]
# ```cpp
# /*
#  * Template for using hash set to find duplicates.
#  */
# bool findDuplicates(vector<Type>& keys) {
#     // Replace Type with actual type of your key
#     unordered_set<Type> hashset;
#     for (Type key : keys) {
#         if (hashset.count(key) > 0) {
#             return true;
#         }
#         hashset.insert(key);
#     }
#     return false;
# }
#
# ```

# %%
### Java

# %% [markdown]
# ```java
# /*
#  * Template for using hash set to find duplicates.
#  */
# boolean findDuplicates(List<Type> keys) {
#     // Replace Type with actual type of your key
#     Set<Type> hashset = new HashSet<>();
#     for (Type key : keys) {
#         if (hashset.contains(key)) {
#             return true;
#         }
#         hashset.add(key);
#     }
#     return false;
# }
#
#
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def containsDuplicate(self, nums: List[int]) -> bool:
        hash_set = set()
        
        for key in nums:
            if (key in hash_set):
                return True
            hash_set.add(key)
            
        return False;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def singleNumber(self, nums: List[int]) -> int:
        hash_set = set()
        for key in nums:
            if (key in hash_set):
                hash_set.remove(key)
                continue
            hash_set.add(key)
        
        return hash_set.pop()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def intersection(self, nums1: List[int], nums2: List[int]) -> List[int]:
        hash_set1 = set()
        for key in nums1:
            hash_set1.add(key)
            
        hash_set2 = set()
        intersection = set()
        for key in nums2:
            if key in hash_set1 and not key in hash_set2:
                hash_set2.add(key)
                intersection.add(key)
        
        return intersection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    
    def __init__(self):
        self.hash_set = set()
    
    def isHappy(self, n: int) -> bool:
        n = str(n)
        s = 0
        for x in n:
            s += int(x)**2

        print(s)
        
        if s == 1:
            return True
        elif s in self.hash_set:
            return False
        else:
            self.hash_set.add(s)
            return self.isHappy(s)
