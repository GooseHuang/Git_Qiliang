# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution(object):
    def postorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        ans = []
        if root == None:
            return ans
        self.postTraverase(root, ans)
        return ans


    def postTraverase(self, t, ans):
        if t.left:
            self.postTraverase(t.left, ans)
        if t.right:
            self.postTraverase(t.right, ans)
        
        ans.append(t.val)

# %%
root = TreeNode(1)
root.right = TreeNode(2)
root.right.left = TreeNode(3)
s = Solution()
print(s.postorderTraversal(root))

root = None
s = Solution()
print(s.postorderTraversal(root))

root = TreeNode(1)
s = Solution()
print(s.postorderTraversal(root))

root = TreeNode(1)
root.left = TreeNode(2)
s = Solution()
print(s.postorderTraversal(root))

root = TreeNode(1)
root.right = TreeNode(2)
s = Solution()
print(s.postorderTraversal(root))
# Out:
# [3, 2, 1]
# []
# [1]
# [2, 1]
# [2, 1]

# %%
# Red Notebook P50
# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution(object):
    def postorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        ans = []

        if root == None:
            return ans
        
        stack1 = []
        stack2 = []
        stack1.append(root)
        p = root
        while(stack1):
            p = stack1.pop()
            if p.left:
                stack1.append(p.left)
            if p.right:
                stack1.append(p.right)
            stack2.append(p)
        while stack2:
            ans.append(stack2.pop().val)
        return ans

# %%
A = TreeNode('A')
B = TreeNode('B')
C = TreeNode('C')
D = TreeNode('D')
E = TreeNode('E')
F = TreeNode('F')
G = TreeNode('G')
H = TreeNode('H')
I = TreeNode('I')

root = F
F.left = B
B.left = A
B.right = D
D.left = C
D.right = E

F.right = G
G.right = I
I.left = H

s = Solution()
print(s.postorderTraversal(root))
# Out:
# ['A', 'C', 'E', 'D', 'B', 'H', 'I', 'G', 'F']

# %%
print('\n')
print([x.val for x in stack])     
print(ans)

# %%
root = TreeNode(1)
root.right = TreeNode(2)
root.right.left = TreeNode(3)
s = Solution()
print(s.postorderTraversal(root))

root = None
s = Solution()
print(s.postorderTraversal(root))

root = TreeNode(1)
s = Solution()
print(s.postorderTraversal(root))

root = TreeNode(1)
root.left = TreeNode(2)
s = Solution()
print(s.postorderTraversal(root))

root = TreeNode(1)
root.right = TreeNode(2)
s = Solution()
print(s.postorderTraversal(root))
# Out:
# [3, 2]
# []
# [1]
# [2, 1]
# [2]
