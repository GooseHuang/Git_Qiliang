# %%
text = r"""
file:///Users/huangqiliang/Downloads/%E6%B7%B1%E5%BA%A6%E5%AD%A6%E4%B9%A0%20v3.0.0/Part%2002-Module%2001-Lesson%2001_%E7%A5%9E%E7%BB%8F%E7%BD%91%E7%BB%9C%E7%AE%80%E4%BB%8B/34.%20%E5%8F%8D%E5%90%91%E4%BC%A0%E6%92%AD.html
"""
print(text)
# Out:
# file:///Users/huangqiliang/Downloads/%E6%B7%B1%E5%BA%A6%E5%AD%A6%E4%B9%A0%20v3.0.0/Part%2002-Module%2001-Lesson%2001_%E7%A5%9E%E7%BB%8F%E7%BD%91%E7%BB%9C%E7%AE%80%E4%BB%8B/34.%20%E5%8F%8D%E5%90%91%E4%BC%A0%E6%92%AD.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
