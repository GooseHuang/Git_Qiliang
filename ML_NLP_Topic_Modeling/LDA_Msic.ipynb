# %%
import numpy as np

# %%
"""

知道 1 和 3 求二   （3是训练好的）

还有是知道1 去求出3   分类

有什么可行的办法

预先打标需要哪些？

1已经有了    



有什么临时可行的方法？

样本参数值    打分   模拟


假设有了2  和   1   现在求3


单点微调和共鸣的  通过调整3， 和2相乘 ， 使最后的结果和1最接近


"""

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = np.array([0.1,0.8,0.1])

# %%
b = np.array([
            [0.4,0.4,0.1,0.1],
            [0.1,0.2,0.5,0.2],
            [0.1,0.05,0.05,0.8],
             ])

# %%
np.dot(a,b)
# Out:
# array([0.13 , 0.205, 0.415, 0.25 ])

# %%
np.dot(a,b).sum()
# Out:
# 1.0000000000000002

# %%
z
