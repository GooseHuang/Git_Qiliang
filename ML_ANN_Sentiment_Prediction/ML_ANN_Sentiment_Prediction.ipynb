# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## May check later   这里为什么就是layer2 error？
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 要学会观察环境
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Threshold 在这里是怎样选择的？

# %% [markdown]
# #### 因为训练的时候只是差异化loss function  当时不用在乎这个

# %% [markdown]
# ### 某个无关紧要的单词可能造成大量的噪音
# ### 加上和不加上某个条件时候的变化
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 会造成其他更重要的单词可能就没有权重
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Words with no meanings:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 有监督的学习   先见到样例

# %% [markdown]
# ## Zeros are not working and making the model in low effeciency:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 其实只需要对1的位置进行计算
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Weifgt_0_1
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Layer1 delta
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 为什么可以这样推出来？ 神经网络推出事情的相似度
#
# ##### 相似的词，相似的weight
# ![image.png](attachment:image.png)

# %% [markdown]
# #### TSNE
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
