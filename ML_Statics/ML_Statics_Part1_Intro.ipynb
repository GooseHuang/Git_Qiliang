# %% [markdown]
# #### 样本均值的分布
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 避免积累信息的干扰项
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Z-score
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 相关性不是因果
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 可能只是自然的波动

# %% [markdown]
# ## Larger Sample
# ![image.png](attachment:image.png)

# %%
sigmal_of_mean = 16.04/250**0.5
sigmal_of_mean
# Out:
# 1.014458673382016

# %% [markdown]
# ### 有一个基准的Mean 作为了 我们的目标

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
(40-37.72)/sigmal_of_mean
# Out:
# 2.247504072688251

# %%
import pandas as pd

# %%
df = pd.read_excel('./Klout scores (Lesson 7).xlsx',header=None)
df.head()
# Out:
#            0
# 0  25.104179
# 1  60.908747
# 2  23.222238
# 3  51.553491
# 4  22.629690

# %%
df[0][774]
# Out:
# 26.7788616597467

# %%
df.iloc[[1,234,457,728,987],0]
# Out:
# 1      60.908747
# 234    53.177807
# 457    14.461961
# 728    13.139507
# 987    52.555271
# Name: 0, dtype: float64

# %%
df.iloc[[1,234,457,728,987],0].mean()
# Out:
# 38.84865863611136

# %%
df.iloc[[1,234,457,728,987,123,456,54,88,846],0].mean()
# Out:
# 34.55026202898124

# %% [markdown]
# ![image.png](attachment:image.png)
