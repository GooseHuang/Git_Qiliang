# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Softmax
# ![image.png](attachment:image.png)

# %%
"""
Why we choose this?


其他方式可以吗？？？

"""

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Softmax
import matplotlib.pyplot as plt
import numpy as np

font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 12,
        }


X = np.arange(-4,4,0.1)
Y = np.exp(X)

plt.title('')
plt.xlabel('x', fontdict=font)
plt.ylabel('exp(x)',fontdict=font)
plt.scatter(X,Y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How bad the model is?
#
# ### Cross entropy value
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 0到1之间很适合交叉熵

# %% [markdown]
# ### 数学是各种可利用的转换关系

# %% [markdown]
# ![image.png](attachment:image.png)
