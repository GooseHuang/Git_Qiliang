# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Unique Email Address
class Solution:
    def numUniqueEmails(self, emails: List[str]) -> int:
        def parser(email):
            at_sign = max([i for i,x in enumerate(email) if x=='@'])
            name_part = email[:at_sign]
            domain_part = email[at_sign:]
            name_part = name_part.split('+')[0].replace('.','')
            clean_email = name_part + domain_part
            return clean_email
        
        email_set = set()
        for x in emails:
            email_set.add(parser(x))
        
        return len(email_set)

# %%
# Approach 1: Linear Iteration
class Solution:
    def numUniqueEmails(self, emails: List[str]) -> int:
        # Hash set to store all the unique emails.
        uniqueEmails = set()

        # Iterate over each character in email.
        for email in emails:
            cleanMail = []

            # Iterate over each character in email.
            for currChar in email:
                # Stop adding characters to localName.
                if currChar == '+' or currChar == '@':
                    break

                # Add this character if not '.'.
                if currChar != '.':
                    cleanMail.append(currChar)

            # Compute domain name (substring from end to '@').
            domainName = []
            for currChar in reversed(email):
                domainName.append(currChar)
                if currChar == '@':
                    break

            # Reverse domain name and append to local name.
            domainName = ''.join(domainName[::-1])
            cleanMail = ''.join(cleanMail)
            uniqueEmails.add(cleanMail + domainName)

        return len(uniqueEmails)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Odd Even Jump

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# License Key Formatting
from collections import deque
class Solution:
    def licenseKeyFormatting(self, s: str, k: int) -> str:
        base = ''
        count=0
        result = deque()
        for i in range(len(s)-1,-1,-1):
            # print(i)
            x = s[i]
            if x=='-':
                continue
            base = x.upper() + base
            count+=1
            if count==k:
                result.appendleft(base)
                base=''
                count=0
        if base:
            result.appendleft(base)
        return '-'.join(result)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Fruit Into Baskets

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.quora.com/What-happens-during-a-Google-hiring-committee-meeting

# %% [markdown]
# ![image.png](attachment:image.png)
