# %% [markdown]
# ## Word Embedding    更好的词之间关系的表示

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Risks
# ![image.png](attachment:image.png)

# %% [markdown]
# ### One hot encoded words
# ![image.png](attachment:image.png)

# %% [markdown]
# ### one hot encoding
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Zero values everywhere!
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Embedding Lookup
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 我可以通过某种方法，去控制和代表某些词之间的距离

# %% [markdown]
# ### 别怕，保持好的假设，继续去学

# %% [markdown]
# ### 去发现和知道的方法

# %% [markdown]
# ## 自己训练出的Skip-Grams 有问题，根本不相似  要查查
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 要收集检验自己结果的方法，和别人以及外界做对比
# ![image.png](attachment:image.png)
