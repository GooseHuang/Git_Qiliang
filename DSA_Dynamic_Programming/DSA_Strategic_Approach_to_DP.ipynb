# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def __init__(self):
        self.steps_dict = {}
    
    def climbStairs(self, n: int) -> int:
        if n < 0:
            return 0
        elif n <= 1:
            return 1
        
        if n in self.steps_dict:
            return self.steps_dict[n]
        
        else:
            steps = self.climbStairs(n-1) + self.climbStairs(n-2)
            self.steps_dict[n] = steps
        
            return steps

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python

# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        def dp(i): 
            """A function that returns the answer to the problem for a given state."""
            # Base cases: when i is less than 3 there are i ways to reach the ith stair.
            if i <= 2: 
                return i
            
            # If i is not a base case, then use the recurrence relation.
            return dp(i - 1) + dp(i - 2)
        
        return dp(n)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python

# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        def dp(i):
            if i <= 2: 
                return i
            if i not in memo:
                # Instead of just returning dp(i - 1) + dp(i - 2), calculate it once and then
                # store the result inside a hashmap to refer to in the future.
                memo[i] = dp(i - 1) + dp(i - 2)
            
            return memo[i]
        
        memo = {}
        return dp(n)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python

# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        if n == 1:
            return 1
            
        # An array that represents the answer to the problem for a given state
        dp = [0] * (n + 1)
        dp[1] = 1 # Base cases
        dp[2] = 2 # Base cases
        
        for i in range(3, n + 1):
            dp[i] = dp[i - 1] + dp[i - 2] # Recurrence relation

        return dp[n]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python
class Solution:
    
    def helper(self, nums, k, memo):
        if k==0:
            return 0
        
        if k==1:
            return nums[-k]
        
        if k in memo:
            return memo[k]
        
        if k ==2:
            memo[k] = max(nums[-k:])
            return memo[k]
        
        # way1
        value1 = nums[-k] + self.helper(nums,k-2, memo)
        
        # way2
        value2 = nums[-k+1] + self.helper(nums, k-3, memo) 
        
        memo[k] = max(value1, value2)
        return memo[k]
        
    
    
    def rob(self, nums: List[int]) -> int:
        memo = {}
        return self.helper(nums,len(nums), memo)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python
class Solution:
    def rob(self, nums: List[int]) -> int:
        def dp(i):
            # Base cases
            if i == 0: 
                return nums[0]            
            if i == 1: 
                return max(nums[0], nums[1])            
            if i not in memo:
                memo[i] = max(dp(i - 1), dp(i - 2) + nums[i]) # Recurrence relation
            return memo[i]
        
        memo = {}
        return dp(len(nums) - 1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python
class Solution:
    def rob(self, nums: List[int]) -> int:
        if len(nums) == 1: 
            return nums[0]
        
        dp = [0] * len(nums)
        
        # Base cases
        dp[0] = nums[0]
        dp[1] = max(nums[0], nums[1])
        
        for i in range(2, len(nums)):
            dp[i] = max(dp[i - 1], dp[i - 2] + nums[i]) # Recurrence relation
        
        return dp[-1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        def dp(i):
            # Base cases
            if i <= 1: 
                return 0                       
            if i not in memo:
                memo[i] = min(dp(i - 1) + cost[i-1], dp(i - 2) + cost[i-2]) # Recurrence relation
            return memo[i]
        
        memo = {}
        return dp(len(cost))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python
class Solution:
    def tribonacci(self, n: int) -> int:
        def dp(i):
            # Base cases
            if i == 0:
                return 0
            elif i<=2:
                return 1
            else:
                if i not in memo:
                    memo[i] = dp(i-1) + dp(i-2) + dp(i-3) # Recurrence relation
                return memo[i]
        
        memo = {}
        return dp(n)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = {'a':1,'b':2}
b = {'b':2,'a':1}

# %%
str(a)
# Out:
# "{'a': 1, 'b': 2}"

# %%
str(b)
# Out:
# "{'b': 2, 'a': 1}"

# %%
# Time exceeded
import copy
from collections import Counter


class Solution:
    def deleteAndEarn(self, nums: List[int]) -> int:

        def dp(tmp_dict):
            if len(tmp_dict)==0:
                return 0

            hash_index = str([(k,tmp_dict[k]) for k in sorted(tmp_dict.keys())] )
            
            if hash_index in memo:
                return  memo[hash_index]
            
            result_list = []
            for k in tmp_dict.keys():
                tmp = copy.copy(tmp_dict)
                tmp[k] -= 1
                if tmp[k]==0:
                    del tmp[k]
                if k-1 in tmp:
                    del tmp[k-1]
                if k+1 in tmp:
                    del tmp[k+1]
                
                value = k + dp(tmp) 
                result_list.append(value)
            
            value = max(result_list)
            memo[hash_index] = value
            
            return memo[hash_index] 
        
        memo = {}
        nums_dict = Counter(nums)
        return dp(nums_dict)

# %%
class Solution(object):
    def deleteAndEarn(self, nums):
        count = collections.Counter(nums)
        prev = None
        avoid = using = 0
        for k in sorted(count):
            if k - 1 != prev:
                avoid, using = max(avoid, using), k * count[k] + max(avoid, using)
            else:
                avoid, using = max(avoid, using), k * count[k] + avoid
            prev = k
        return max(avoid, using)

# %%
avoid = using = 0

# %%
avoid
# Out:
# 0

# %%
using
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def rob(self, nums: List[int]) -> int:

        def dp(i: int) -> int:
            # Base cases
            if i == 0:
                return nums[0]
            elif i == 1:
                return max(nums[0], nums[1])
            
            if i not in memo:
                # Use recurrence relation to calculate dp[i].
                memo[i] = max(dp(i - 1), dp(i - 2) + nums[i])
            
            return memo[i]
        
        memo = {}
        return dp(len(nums) - 1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def rob(self, nums: List[int]) -> int:        
        n = len(nums)
        dp = [0] * n
        
        return dp[n - 1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def rob(self, nums: List[int]) -> int:   
        n = len(nums)
        if n == 1:
            return nums[0]
        dp = [0] * n
        
        #Base Cases
        dp[0] = nums[0]
        dp[1] = max(nums[0], nums[1])
        
        return dp[n - 1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def rob(self, nums: List[int]) -> int:   
        n = len(nums)
        if n == 1:
            return nums[0]
        dp = [0] * n
        
        #Base Cases
        dp[0] = nums[0]
        dp[1] = max(nums[0], nums[1])
        
        for i in range(2, n):
            pass
        
        return dp[n - 1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def rob(self, nums: List[int]) -> int:   
        n = len(nums)
        if n == 1:
            return nums[0]
        dp = [0] * n
        
        #Base Cases
        dp[0] = nums[0]
        dp[1] = max(nums[0], nums[1])
        
        for i in range(2, n):
            # Use recurrence relation to calculate dp[i].
            dp[i] = max(dp[i - 1], dp[i - 2] + nums[i])
        
        return dp[n - 1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def maximumScore(self, nums: List[int], multipliers: List[int]) -> int:
        # lru_cache from functools automatically memoizes the function
        @lru_cache(2000)
        def dp(i, left):
            # Base case
            if i == m:
                return 0

            mult = multipliers[i]
            right = n - 1 - (i - left)
            
            # Recurrence relation
            return max(mult * nums[left] + dp(i + 1, left + 1), 
                       mult * nums[right] + dp(i + 1, left))
                       
        n, m = len(nums), len(multipliers)
        return dp(0, 0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def maximumScore(self, nums: List[int], multipliers: List[int]) -> int:
        n, m = len(nums), len(multipliers)
        dp = [[0] * (m + 1) for _ in range(m + 1)]
        
        for i in range(m - 1, -1, -1):
            for left in range(i, -1, -1):
                mult = multipliers[i]
                right = n - 1 - (i - left)
                dp[i][left] = max(mult * nums[left] + dp[i + 1][left + 1], 
                                  mult * nums[right] + dp[i + 1][left])        
        return dp[0][0]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Time Exceeded

class Solution:
    def __init__(self):
        self.memo = {}
    
    
    def maximumScore(self, nums: List[int], multipliers: List[int]) -> int:    
        return self.helper(0,0,len(nums)-1, nums, multipliers)
        
    
    def helper(self, i, start, end, nums, multipliers):
        if i==len(multipliers):
            return 0
        
        
        if (i,start,end) in self.memo:
            return self.memo[(i,start,end)] 
        
        
        if start == end:
            self.memo[(i,start,end)] = multipliers[i]*nums[start]
            
        else:
            # case1
            case1 = multipliers[i]*nums[start] + self.helper(i+1, start+1, end, nums, multipliers) 
            
            # case2
            case2 = multipliers[i]*nums[end] + self.helper(i+1, start, end-1, nums, multipliers)
        
            if case1 > case2:
                self.memo[(i,start,end)] = case1
            else:
                self.memo[(i,start,end)] = case2
        
        return self.memo[(i,start,end)]

# %%
# Accepted
class Solution:
   
    def maximumScore(self, nums: List[int], multipliers: List[int]) -> int:    

        @lru_cache(2000)
        def helper(i, start, end):
            if i==len(multipliers):
                return 0

            if start == end:
                return multipliers[i]*nums[start]

            else:
                # case1
                case1 = multipliers[i]*nums[start] + helper(i+1, start+1, end) 

                # case2
                case2 = multipliers[i]*nums[end] + helper(i+1, start, end-1)

                if case1 > case2:
                    return case1
                else:
                    return case2

        score = helper(0,0,len(nums)-1)
        helper.cache_clear()
    
        return score

# %%
# Time Exceeded
class Solution:

    # TLE
    def maximumScore(self, nums: List[int], mult: List[int]) -> int:

        def dp(i, left, right):
            if i == len(mult):
                return 0

            return max(
                 mult[i] * nums[left] + dp(i + 1, left + 1, right),
                 mult[i] * nums[right] + dp(i + 1, left, right - 1)
            )
        
        return dp(0, 0, len(nums) - 1)

# %%
# Time Exceeded Memo I
class Solution:
    # MLE
    def maximumScore(self, nums: List[int], mult: List[int]) -> int:

        def dp(i, left):
            if i == len(mult):
                return 0

            if (i, left) not in memo:
                right = len(nums) - 1 - i + left
                memo[(i, left)] = max(
                    mult[i] * nums[left] + dp(i + 1, left + 1),
                    mult[i] * nums[right] + dp(i + 1, left)
                )

            return memo[(i, left)]
        
        memo = {}
        return dp(0, 0)

# %%
# Accecpted Iteration   Not Fully Understand Yet
class Solution:

    def maximumScore(self, nums: List[int], mult: List[int]) -> int:
        n, m = len(nums), len(mult)
        dp = [[0 for _ in range(m + 1)] for _ in range(m + 1)]

        for i in range(m - 1, -1, -1):
            for left in range(i, -1, -1):
                right = n - 1 - i + left
                dp[i][left] = max(mult[i] * nums[left] + dp[i + 1][left + 1], 
                                  mult[i] * nums[right] + dp[i + 1][left])

        return dp[0][0]

# %%
# Lru Cache Time Exceed
class Solution:

    # O(m^2) time | O(m^2) space
    def maximumScore(self, nums: List[int], mult: List[int]) -> int:

        @lru_cache(None)
        def dp(i, left):
            if i == len(mult):
                return 0

            right = len(nums) - 1 - i + left
            return max(
                mult[i] * nums[left] + dp(i + 1, left + 1),
                mult[i] * nums[right] + dp(i + 1, left)
            )
        
        score = dp(0, 0)
        dp.cache_clear()
        return score

# %% [markdown]
# # Longest Common Subsequence

# %% [markdown]
# https://leetcode.com/explore/learn/card/dynamic-programming/631/strategy-for-solving-dp-problems/4045/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random

# %%
base = 'abcdefghijklmnopqrstuvwx
yz'
''.join(random.choices(base,k=10))
# Out:
# 'wrcwcxwxht'

# %% [markdown]
# #### Solutions
# https://leetcode.com/problems/longest-common-subsequence/solution/

# %%
"""
A-G
C-T

AGCT

ATGCCE

"""

# %%
class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        def dp(txt1,txt2):
            # print(memo)
            if len(txt1)==1:
                if txt1 in txt2:
                    return 1
                else:
                    return 0

            if (txt1, txt2) not in memo:
                if not txt1[0] in txt2:
                    memo[(txt1,txt2)] = dp(txt1[1:], txt2)

                else:
                    j = txt2.index(txt1[0])
                    memo[(txt1, txt2)] = max(1 + dp(txt1[1:], txt2[j:]),
                                             dp(txt1[1:], txt2)
                                            )
            
            return memo[(txt1,txt2)]
        
        memo = {}
        return dp(text1,text2)

# %%
# Time Exceeded v1
pr = print

class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        def dp(txt1,txt2):
            
            if len(txt1)==0 or len(txt2)==0:
                return 0
            
            
            # print(memo)
            if len(txt1)==1:
                if txt1 in txt2:
                    return 1
                else:
                    return 0
                
                
            

            if (txt1, txt2) not in memo:
                if not txt1[0] in txt2:
                    #pr(2.1)
                    memo[(txt1,txt2)] = dp(txt1[1:], txt2)

                else:
                    #pr(2.2)
                    j = txt2.index(txt1[0])
                    memo[(txt1, txt2)] = max(1 + dp(txt1[1:], txt2[j+1:]),
                                             dp(txt1[1:], txt2)
                                            )
            
            return memo[(txt1,txt2)]
        
        memo = {}
        common = set(text1) & set(text2)
        text1 = ''.join([x for x in text1 if x in common])
        text2 = ''.join([x for x in text2 if x in common])
        result = dp(text1,text2)
        print(memo)
        return result

# %%
# Time Exceeded v2
pr = print

class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        def dp(txt1,txt2):

            
            if len(txt1)==0 or len(txt2)==0:
                return 0

            # print(memo)
            if len(txt1)==1:
                if txt1 in txt2:
                    return 1
                else:
                    return 0
                    
            if (txt1, txt2) not in memo:
                common = set(txt1) & set(txt2)
                new_txt1 = ''.join([x for x in txt1 if x in common])
                new_txt2 = ''.join([x for x in txt2 if x in common])
                
                if not new_txt1 or not new_txt2:
                    memo[(txt1,txt2)] = 0

                elif not new_txt1[0] in new_txt2:
                    #pr(2.1)
                    memo[(txt1,txt2)] = dp(new_txt1[1:], new_txt2)

                else:
                    #pr(2.2)
                    j = new_txt2.index(new_txt1[0])
                    memo[(txt1, txt2)] = max(1 + dp(new_txt1[1:], new_txt2[j+1:]),
                                             dp(new_txt1[1:], new_txt2)
                                            )
            
            return memo[(txt1,txt2)]
        
        memo = {}
        common = set(text1) & set(text2)
        text1 = ''.join([x for x in text1 if x in common])
        text2 = ''.join([x for x in text2 if x in common])
        result = dp(text1,text2)
        print(memo)
        return result

# %%
# Accepted v1
from functools import lru_cache

class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        
        @lru_cache(maxsize=None)
        def memo_solve(p1, p2):
            
            # Base case: If either string is now empty, we can't match
            # up anymore characters.
            if p1 == len(text1) or p2 == len(text2):
                return 0
            
            # Option 1: We don't include text1[p1] in the solution.
            option_1 = memo_solve(p1 + 1, p2)
            
            # Option 2: We include text1[p1] in the solution, as long as
            # a match for it in text2 at or after p2 exists.
            first_occurence = text2.find(text1[p1], p2)
            option_2 = 0
            if first_occurence != -1:
                option_2 = 1 + memo_solve(p1 + 1, first_occurence + 1)
            
            # Return the best option.
            return max(option_1, option_2)
                
        return memo_solve(0, 0)

# %%
# Better v2
from functools import lru_cache
class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        
        @lru_cache(maxsize=None)
        def memo_solve(p1, p2):
            
            # Base case: If either string is now empty, we can't match
            # up anymore characters.
            if p1 == len(text1) or p2 == len(text2):
                return 0
            
            # Recursive case 1.
            if text1[p1] == text2[p2]:
                return 1 + memo_solve(p1 + 1, p2 + 1)
            
            # Recursive case 2.
            else:
                return max(memo_solve(p1, p2 + 1), memo_solve(p1 + 1, p2))
            
        return memo_solve(0, 0)

# %%
# Bottom up
class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        
        # Make a grid of 0's with len(text2) + 1 columns 
        # and len(text1) + 1 rows.
        dp_grid = [[0] * (len(text2) + 1) for _ in range(len(text1) + 1)]
        
        # Iterate up each column, starting from the last one.
        for col in reversed(range(len(text2))):
            for row in reversed(range(len(text1))):
                # If the corresponding characters for this cell are the same...
                if text2[col] == text1[row]:
                    dp_grid[row][col] = 1 + dp_grid[row + 1][col + 1]
                # Otherwise they must be different...
                else:
                    dp_grid[row][col] = max(dp_grid[row + 1][col], dp_grid[row][col + 1])
        
        # The original problem's answer is in dp_grid[0][0]. Return it.
        return dp_grid[0][0]

# %%
# Approach 4: Dynamic Programming with Space Optimization
class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        
        # If text1 doesn't reference the shortest string, swap them.
        if len(text2) < len(text1):
            text1, text2 = text2, text1
        
        
        # The previous column starts with all 0's and like before is 1
        # more than the length of the first word.
        previous = [0] * (len(text1) + 1)
        
        # Iterate up each column, starting from the last one.
        for col in reversed(range(len(text2))):
            # Create a new array to represent the current column.
            current = [0] * (len(text1) + 1)
            for row in reversed(range(len(text1))):
                if text2[col] == text1[row]:
                    current[row] = 1 + previous[row + 1]
                else:
                    current[row] = max(previous[row], current[row + 1])
            # The current column becomes the previous one.
            previous = current
        
        # The original problem's answer is in previous[0]. Return it.
        return previous[0]

# %% [markdown]
# # Maximal Square

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Accepted
pr = print
class Solution:
    def maximalSquare(self, matrix: List[List[str]]) -> int:
        if not matrix:
            return 0
        
        level = 1
        for i in range(len(matrix)):
            for j in range(len(matrix[0])):
                if matrix[i][j]=="1":
                    level_up = True
                    while(level_up):
                        if i+level > len(matrix) or j+level > len(matrix[0]):
                            break
                        for x in range(i, i+level):
                            for y in range(j, j+level):
                                if matrix[x][y]=="0":
                                    level_up=False
                                    break
                            if not level_up:
                                break
                        if level_up:
                            level += 1
        return (level-1)*(level-1)

# %% [markdown]
# #### Solutions
# https://leetcode.com/problems/maximal-square/solution/

# %% [markdown]
# ##### Approach #2 (Dynamic Programming) [Accepted]
#
#
# ![image.png](attachment:image.png)
#
#
# ```java
#
# public class Solution {
#     public int maximalSquare(char[][] matrix) {
#         int rows = matrix.length, cols = rows > 0 ? matrix[0].length : 0;
#         int[][] dp = new int[rows + 1][cols + 1];
#         int maxsqlen = 0;
#         for (int i = 1; i <= rows; i++) {
#             for (int j = 1; j <= cols; j++) {
#                 if (matrix[i-1][j-1] == '1'){
#                     dp[i][j] = Math.min(Math.min(dp[i][j - 1], dp[i - 1][j]), dp[i - 1][j - 1]) + 1;
#                     maxsqlen = Math.max(maxsqlen, dp[i][j]);
#                 }
#             }
#         }
#         return maxsqlen * maxsqlen;
#     }
# }
# ```

# %% [markdown]
# ##### Approach #3 (Better Dynamic Programming) [Accepted]
# ```java
# public class Solution {
#     public int maximalSquare(char[][] matrix) {
#         int rows = matrix.length, cols = rows > 0 ? matrix[0].length : 0;
#         int[] dp = new int[cols + 1];
#         int maxsqlen = 0, prev = 0;
#         for (int i = 1; i <= rows; i++) {
#             for (int j = 1; j <= cols; j++) {
#                 int temp = dp[j];
#                 if (matrix[i - 1][j - 1] == '1') {
#                     dp[j] = Math.min(Math.min(dp[j - 1], prev), dp[j]) + 1;
#                     maxsqlen = Math.max(maxsqlen, dp[j]);
#                 } else {
#                     dp[j] = 0;
#                 }
#                 prev = temp;
#             }
#         }
#         return maxsqlen * maxsqlen;
#     }
# }
# ```

# %% [markdown]
# ![image.png](attachment:image.png)
